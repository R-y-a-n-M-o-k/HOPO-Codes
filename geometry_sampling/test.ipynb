# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(55, 180, 100)
x_eq = 113.04244011
z = (x-x_eq)*np.pi/180

f = -0.91334819 + 10764.035*z**2 - 6290.1980*z**3 + 526.76432*z**4 - 1098.6327*z**5 + 1669.8193*z**6 - 1398.7498*z**7 + 502.39223*z**8

# %%
plt.figure
plt.plot(x, f)
